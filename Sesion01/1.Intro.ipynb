# %%
# print("hooolis")

# %%
# comentarios

# Identación

# a = 10

# if a == 9:
#    print('si son iguales')
#    print('si cumple')
# else: print('no cumple')

#

# %%
# Listas -> versátiles

# lista1 = [1, 2, 3]
# lista vacía = []

# Operador de índice -> []
# Van desde el 0 hasta n-1

# Tuplas -> no se pueden modificar una vez creadas

# tupla1 = ()

# Diccionarios -> {clave1: valor1, clave2: valor2, clave3: valor3}

# diccionario_persona1 = {'nombre': 'juan', 'edad': 10, 'direccion': 'cordoba'}

# %%
# Control de flujo

var1 = 5

if var1 == 5:
        print('si cumple')
else: ('no cumple')
# Out:
# si cumple

# %%
# for y while -> nos permiten iterar

numeros = [1, 2, 5, 6, 7, 9, 10]

suma = 0

for val in numeros:
    suma = suma + val
    print(suma)
# Out:
# 1
# 3
# 8
# 14
# 21
# 30
# 40
